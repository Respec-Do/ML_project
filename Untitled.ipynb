# %%
import pandas as pd

h_df = pd.read_csv('./datasets/HCV-Egy-Data.csv')
h_df
# Out:
#       Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0       56       1   35      2               1          1          1
# 1       46       1   29      1               2          2          1
# 2       57       1   33      2               2          2          2
# 3       49       2   33      1               2          1          2
# 4       59       1   32      1               1          2          1
# ...    ...     ...  ...    ...             ...        ...        ...
# 1380    44       1   29      1               2          2          2
# 1381    55       1   34      1               2          2          1
# 1382    42       1   26      2               2          1          1
# 1383    52       1   29      2               1          1          2
# 1384    55       2   26      1               2          2          2
#
#       Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# 0                                    2          2                 2  ...
# 1                                    2          2                 1  ...
# 2                                    1          1                 1  ...
# 3                                    1          2                 1  ...
# 4                                    2          2                 2  ...
# ...                                ...        ...               ...  ...
# 1380                                 1          1                 1  ...
# 1381                                 1          1                 1  ...
# 1382                                 1          2                 1  ...
# 1383                                 2          2                 1  ...
# 1384                                 1          2                 1  ...
#
#       ALT 36  ALT 48  ALT after 24 w  RNA Base   RNA 4   RNA 12  RNA EOT  \
# 0          5       5               5    655330  634536   288194        5
# 1         57     123              44     40620  538635   637056   336804
# 2          5       5               5    571148  661346        5   735945
# 3         48      77              33   1041941  449939   585688   744463
# 4         94      90              30    660410  738756  3731527   338946
# ...      ...     ...             ...       ...     ...      ...      ...
# 1380      63      44              45    387795   55938        5        5
# 1381      97      64              41    481378  152961   393339    73574
# 1382      87      39              24    612664  572756   806109   343719
# 1383      48      81              43    139872   76161   515730     2460
# 1384      64      71              34   1190577  628730        5        5
#
#       RNA EF  Baseline histological Grading  Baselinehistological staging
# 0          5                             13                             2
# 1      31085                              4                             2
# 2     558829                              4                             4
# 3     582301                             10                             3
# 4     242861                             11                             1
# ...      ...                            ...                           ...
# 1380       5                             15                             4
# 1381  236273                             10                             2
# 1382  160457                              6                             2
# 1383  696074                             15                             3
# 1384       5                             13                             3
#
# [1385 rows x 29 columns]

# %%
h_df.columns
# Out:
# Index(['Age ', 'Gender', 'BMI', 'Fever', 'Nausea/Vomting', 'Headache ',
#        'Diarrhea ', 'Fatigue & generalized bone ache ', 'Jaundice ',
#        'Epigastric pain ', 'WBC', 'RBC', 'HGB', 'Plat', 'AST 1', 'ALT 1',
#        'ALT4', 'ALT 12', 'ALT 24', 'ALT 36', 'ALT 48', 'ALT after 24 w',
#        'RNA Base', 'RNA 4', 'RNA 12', 'RNA EOT', 'RNA EF',
#        'Baseline histological Grading', 'Baselinehistological staging'],
#       dtype='object')

# %%
d_df = pd.read_csv('./datasets/Discretization-Criteria.csv')
d_df
# Out:
#                     Feature Names   Feature Values  \
# 0                             Age            32:61
# 1                          Gender      Male,Female
# 2            BMI(Body Mass Index)            22:35
# 3                           Fever  Absent, Present
# 4                 Nausea/Vomiting  Absent, Present
# 5                        Headache  Absent, Present
# 6                        Diarrhea  Absent, Present
# 7                         Fatigue  Absent, Present
# 8                       Bone ache  Absent, Present
# 9                        Jaundice  Absent, Present
# 10                Epigastria pain  Absent, Present
# 11         WBC(White Blood Cells)       2991:12101
# 12           RBC(Red Blood Cells)  3816422:5018451
# 13                HGB(Hemoglobin)             2:20
# 14                 Plat(Platelet)     93013:226464
# 15                   AST1(1 week)      0.088888889
# 16                   ALT1(1 week)      0.088888889
# 17                  ALT4(4 weeks)      0.088888889
# 18                ALT12(12 weeks)      0.088888889
# 19                ALT24(24 weeks)      0.088888889
# 20                ALT36(36 weeks)      0.088888889
# 21                ALT48(48 weeks)      0.088888889
# 22                       RNA Base        0:1201086
# 23                          RNA 4        0:1201715
# 24                         RNA 12        0:3731527
# 25                        RNA EOT         0:808450
# 26      RNA EF(Elongation Factor)         0:808450
# 27  Baseline Histological Grading             1:16
# 28          Baseline Histological            F0:F4
#
#                                Discretization (Items)
# 0   [0; 32], ]32; 37], ]37; 42],]42; 47], ]47; 52]...
# 1                                    [Male], [Female]
# 2   [0; 18:5[ [18:5; 25[, [25; 30[, [30; 35[, [35;...
# 3                               [Absent], [Present] -
# 4                               [Absent], [Present] -
# 5                               [Absent], [Present] -
# 6                               [Absent], [Present] -
# 7                               [Absent], [Present] -
# 8                               [Absent], [Present] -
# 9                               [Absent], [Present] -
# 10                              [Absent], [Present] -
# 11           [0; 4000[, [4000; 11000[, [11000; 12101]
# 12  [0; 3000000[, [3000000; 5000000[,[5000000; 501...
# 13  If (Gender==[Male]):[2; 14[, [14; 17:5], ]17:5...
# 14  [93013; 100000[, [100000; 255000[,[255000; 226...
# 15                       [0; 20[, [20; 40], ]40; 128]
# 16                       [0; 20[, [20; 40], ]40; 128]
# 17                       [0; 20[, [20; 40], ]40; 128]
# 18                       [0; 20[, [20; 40], ]40; 128]
# 19                       [0; 20[, [20; 40], ]40; 128]
# 20                       [0; 20[, [20; 40], ]40; 128]
# 21                       [0; 20[, [20; 40], ]40; 128]
# 22                               [0; 5], ]5; 1201086]
# 23                               [0; 5], ]5; 1201715]
# 24                               [0; 5], ]5; 3731527]
# 25                                [0; 5], ]5; 808450]
# 26                                [0; 5], ]5; 808450]
# 27                             [1]; [2]; [3]; :::[16]
# 28  [No Fibrosis], [Portal Fibrosis],Staging (Clas...

# %%
d_df.loc[28, :]['Discretization (Items)']
# Out:
# '[No Fibrosis], [Portal Fibrosis],Staging (Class Label) [Few Septa], [Many Septa], [Cirrhosis]'

# %%
h_df['Baselinehistological staging'].value_counts()
# Out:
# Baselinehistological staging
# 4    362
# 3    355
# 1    336
# 2    332
# Name: count, dtype: int64

# %%
h_df['Baseline histological Grading'].value_counts()
# Out:
# Baseline histological Grading
# 15    139
# 11    121
# 14    106
# 9     103
# 6     102
# 12    101
# 8      97
# 13     95
# 4      94
# 5      93
# 3      89
# 10     87
# 16     86
# 7      72
# Name: count, dtype: int64

# %%
h_df
# Out:
#       Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0       56       1   35      2               1          1          1
# 1       46       1   29      1               2          2          1
# 2       57       1   33      2               2          2          2
# 3       49       2   33      1               2          1          2
# 4       59       1   32      1               1          2          1
# ...    ...     ...  ...    ...             ...        ...        ...
# 1380    44       1   29      1               2          2          2
# 1381    55       1   34      1               2          2          1
# 1382    42       1   26      2               2          1          1
# 1383    52       1   29      2               1          1          2
# 1384    55       2   26      1               2          2          2
#
#       Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# 0                                    2          2                 2  ...
# 1                                    2          2                 1  ...
# 2                                    1          1                 1  ...
# 3                                    1          2                 1  ...
# 4                                    2          2                 2  ...
# ...                                ...        ...               ...  ...
# 1380                                 1          1                 1  ...
# 1381                                 1          1                 1  ...
# 1382                                 1          2                 1  ...
# 1383                                 2          2                 1  ...
# 1384                                 1          2                 1  ...
#
#       ALT 36  ALT 48  ALT after 24 w  RNA Base   RNA 4   RNA 12  RNA EOT  \
# 0          5       5               5    655330  634536   288194        5
# 1         57     123              44     40620  538635   637056   336804
# 2          5       5               5    571148  661346        5   735945
# 3         48      77              33   1041941  449939   585688   744463
# 4         94      90              30    660410  738756  3731527   338946
# ...      ...     ...             ...       ...     ...      ...      ...
# 1380      63      44              45    387795   55938        5        5
# 1381      97      64              41    481378  152961   393339    73574
# 1382      87      39              24    612664  572756   806109   343719
# 1383      48      81              43    139872   76161   515730     2460
# 1384      64      71              34   1190577  628730        5        5
#
#       RNA EF  Baseline histological Grading  Baselinehistological staging
# 0          5                             13                             2
# 1      31085                              4                             2
# 2     558829                              4                             4
# 3     582301                             10                             3
# 4     242861                             11                             1
# ...      ...                            ...                           ...
# 1380       5                             15                             4
# 1381  236273                             10                             2
# 1382  160457                              6                             2
# 1383  696074                             15                             3
# 1384       5                             13                             3
#
# [1385 rows x 29 columns]

# %%
pre_h_df = h_df.copy()

# %%
pre_h_df.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'Age '}>,
#         <Axes: title={'center': 'Gender'}>,
#         <Axes: title={'center': 'BMI'}>,
#         <Axes: title={'center': 'Fever'}>,
#         <Axes: title={'center': 'Nausea/Vomting'}>],
#        [<Axes: title={'center': 'Headache '}>,
#         <Axes: title={'center': 'Diarrhea '}>,
#         <Axes: title={'center': 'Fatigue & generalized bone ache '}>,
#         <Axes: title={'center': 'Jaundice '}>,
#         <Axes: title={'center': 'Epigastric pain '}>],
#        [<Axes: title={'center': 'WBC'}>, <Axes: title={'center': 'RBC'}>,
#         <Axes: title={'center': 'HGB'}>,
#         <Axes: title={'center': 'Plat'}>,
#         <Axes: title={'center': 'AST 1'}>],
#        [<Axes: title={'center': 'ALT 1'}>,
#         <Axes: title={'center': 'ALT4'}>,
#         <Axes: title={'center': 'ALT 12'}>,
#         <Axes: title={'center': 'ALT 24'}>,
#         <Axes: title={'center': 'ALT 36'}>],
#        [<Axes: title={'center': 'ALT 48'}>,
#         <Axes: title={'center': 'ALT after 24 w'}>,
#         <Axes: title={'center': 'RNA Base'}>,
#         <Axes: title={'center': 'RNA 4'}>,
#         <Axes: title={'center': 'RNA 12'}>],
#        [<Axes: title={'center': 'RNA EOT'}>,
#         <Axes: title={'center': 'RNA EF'}>,
#         <Axes: title={'center': 'Baseline histological Grading'}>,
#         <Axes: title={'center': 'Baselinehistological staging'}>,
#         <Axes: >]], dtype=object)

# %%
h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1385 entries, 0 to 1384
# Data columns (total 29 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               1385 non-null   int64
#  1   Gender                            1385 non-null   int64
#  2   BMI                               1385 non-null   int64
#  3   Fever                             1385 non-null   int64
#  4   Nausea/Vomting                    1385 non-null   int64
#  5   Headache                          1385 non-null   int64
#  6   Diarrhea                          1385 non-null   int64
#  7   Fatigue & generalized bone ache   1385 non-null   int64
#  8   Jaundice                          1385 non-null   int64
#  9   Epigastric pain                   1385 non-null   int64
#  10  WBC                               1385 non-null   int64
#  11  RBC                               1385 non-null   float64
#  12  HGB                               1385 non-null   int64
#  13  Plat                              1385 non-null   float64
#  14  AST 1                             1385 non-null   int64
#  15  ALT 1                             1385 non-null   int64
#  16  ALT4                              1385 non-null   float64
#  17  ALT 12                            1385 non-null   int64
#  18  ALT 24                            1385 non-null   int64
#  19  ALT 36                            1385 non-null   int64
#  20  ALT 48                            1385 non-null   int64
#  21  ALT after 24 w                    1385 non-null   int64
#  22  RNA Base                          1385 non-null   int64
#  23  RNA 4                             1385 non-null   int64
#  24  RNA 12                            1385 non-null   int64
#  25  RNA EOT                           1385 non-null   int64
#  26  RNA EF                            1385 non-null   int64
#  27  Baseline histological Grading     1385 non-null   int64
#  28  Baselinehistological staging      1385 non-null   int64
# dtypes: float64(3), int64(26)
# memory usage: 313.9 KB

# %%
h_df.duplicated().sum()
# Out:
# 0

# %%
pre_h_df = h_df.iloc[:,:-2]
pre_h_df
# Out:
#       Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0       56       1   35      2               1          1          1
# 1       46       1   29      1               2          2          1
# 2       57       1   33      2               2          2          2
# 3       49       2   33      1               2          1          2
# 4       59       1   32      1               1          2          1
# ...    ...     ...  ...    ...             ...        ...        ...
# 1380    44       1   29      1               2          2          2
# 1381    55       1   34      1               2          2          1
# 1382    42       1   26      2               2          1          1
# 1383    52       1   29      2               1          1          2
# 1384    55       2   26      1               2          2          2
#
#       Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# 0                                    2          2                 2  ...
# 1                                    2          2                 1  ...
# 2                                    1          1                 1  ...
# 3                                    1          2                 1  ...
# 4                                    2          2                 2  ...
# ...                                ...        ...               ...  ...
# 1380                                 1          1                 1  ...
# 1381                                 1          1                 1  ...
# 1382                                 1          2                 1  ...
# 1383                                 2          2                 1  ...
# 1384                                 1          2                 1  ...
#
#       ALT 12  ALT 24  ALT 36  ALT 48  ALT after 24 w  RNA Base   RNA 4  \
# 0        109      81       5       5               5    655330  634536
# 1         75     113      57     123              44     40620  538635
# 2        107     116       5       5               5    571148  661346
# 3         80      88      48      77              33   1041941  449939
# 4         48     120      94      90              30    660410  738756
# ...      ...     ...     ...     ...             ...       ...     ...
# 1380     106     127      63      44              45    387795   55938
# 1381      99     108      97      64              41    481378  152961
# 1382      61     116      87      39              24    612664  572756
# 1383      74      47      48      81              43    139872   76161
# 1384      68     115      64      71              34   1190577  628730
#
#        RNA 12  RNA EOT  RNA EF
# 0      288194        5       5
# 1      637056   336804   31085
# 2           5   735945  558829
# 3      585688   744463  582301
# 4     3731527   338946  242861
# ...       ...      ...     ...
# 1380        5        5       5
# 1381   393339    73574  236273
# 1382   806109   343719  160457
# 1383   515730     2460  696074
# 1384        5        5       5
#
# [1385 rows x 27 columns]

# %%
pre_h_df['target'] = h_df['Baselinehistological staging']

# %%
pre_h_df
# Out:
#       Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0       56       1   35      2               1          1          1
# 1       46       1   29      1               2          2          1
# 2       57       1   33      2               2          2          2
# 3       49       2   33      1               2          1          2
# 4       59       1   32      1               1          2          1
# ...    ...     ...  ...    ...             ...        ...        ...
# 1380    44       1   29      1               2          2          2
# 1381    55       1   34      1               2          2          1
# 1382    42       1   26      2               2          1          1
# 1383    52       1   29      2               1          1          2
# 1384    55       2   26      1               2          2          2
#
#       Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# 0                                    2          2                 2  ...
# 1                                    2          2                 1  ...
# 2                                    1          1                 1  ...
# 3                                    1          2                 1  ...
# 4                                    2          2                 2  ...
# ...                                ...        ...               ...  ...
# 1380                                 1          1                 1  ...
# 1381                                 1          1                 1  ...
# 1382                                 1          2                 1  ...
# 1383                                 2          2                 1  ...
# 1384                                 1          2                 1  ...
#
#       ALT 24  ALT 36  ALT 48  ALT after 24 w  RNA Base   RNA 4   RNA 12  \
# 0         81       5       5               5    655330  634536   288194
# 1        113      57     123              44     40620  538635   637056
# 2        116       5       5               5    571148  661346        5
# 3         88      48      77              33   1041941  449939   585688
# 4        120      94      90              30    660410  738756  3731527
# ...      ...     ...     ...             ...       ...     ...      ...
# 1380     127      63      44              45    387795   55938        5
# 1381     108      97      64              41    481378  152961   393339
# 1382     116      87      39              24    612664  572756   806109
# 1383      47      48      81              43    139872   76161   515730
# 1384     115      64      71              34   1190577  628730        5
#
#       RNA EOT  RNA EF  target
# 0           5       5       2
# 1      336804   31085       2
# 2      735945  558829       4
# 3      744463  582301       3
# 4      338946  242861       1
# ...       ...     ...     ...
# 1380        5       5       4
# 1381    73574  236273       2
# 1382   343719  160457       2
# 1383     2460  696074       3
# 1384        5       5       3
#
# [1385 rows x 28 columns]

# %%
pre_h_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1385 entries, 0 to 1384
# Data columns (total 28 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               1385 non-null   int64
#  1   Gender                            1385 non-null   int64
#  2   BMI                               1385 non-null   int64
#  3   Fever                             1385 non-null   int64
#  4   Nausea/Vomting                    1385 non-null   int64
#  5   Headache                          1385 non-null   int64
#  6   Diarrhea                          1385 non-null   int64
#  7   Fatigue & generalized bone ache   1385 non-null   int64
#  8   Jaundice                          1385 non-null   int64
#  9   Epigastric pain                   1385 non-null   int64
#  10  WBC                               1385 non-null   int64
#  11  RBC                               1385 non-null   float64
#  12  HGB                               1385 non-null   int64
#  13  Plat                              1385 non-null   float64
#  14  AST 1                             1385 non-null   int64
#  15  ALT 1                             1385 non-null   int64
#  16  ALT4                              1385 non-null   float64
#  17  ALT 12                            1385 non-null   int64
#  18  ALT 24                            1385 non-null   int64
#  19  ALT 36                            1385 non-null   int64
#  20  ALT 48                            1385 non-null   int64
#  21  ALT after 24 w                    1385 non-null   int64
#  22  RNA Base                          1385 non-null   int64
#  23  RNA 4                             1385 non-null   int64
#  24  RNA 12                            1385 non-null   int64
#  25  RNA EOT                           1385 non-null   int64
#  26  RNA EF                            1385 non-null   int64
#  27  target                            1385 non-null   int64
# dtypes: float64(3), int64(25)
# memory usage: 303.1 KB

# %% [markdown]
# 차원축소 진행

# %%
from sklearn.preprocessing import StandardScaler

std = StandardScaler()
result=std.fit_transform(pre_h_df.iloc[:, :-1])
std_pre_h_df = pd.DataFrame(result, columns=pre_h_df.iloc[:, :-1].columns)
std_pre_h_df
# Out:
#           Age     Gender       BMI     Fever  Nausea/Vomting  Headache   \
# 0     1.102814 -0.979276  1.568525  0.969420       -1.005067  -0.992089
# 1    -0.036355 -0.979276  0.096039 -1.031544        0.994959   1.007974
# 2     1.216730 -0.979276  1.077696  0.969420        0.994959   1.007974
# 3     0.305396  1.021163  1.077696 -1.031544        0.994959  -0.992089
# 4     1.444564 -0.979276  0.832282 -1.031544       -1.005067   1.007974
# ...        ...       ...       ...       ...             ...        ...
# 1380 -0.264188 -0.979276  0.096039 -1.031544        0.994959   1.007974
# 1381  0.988897 -0.979276  1.323110 -1.031544        0.994959   1.007974
# 1382 -0.492022 -0.979276 -0.640203  0.969420        0.994959  -0.992089
# 1383  0.647146 -0.979276  0.096039  0.969420       -1.005067  -0.992089
# 1384  0.988897  1.021163 -0.640203 -1.031544        0.994959   1.007974
#
#       Diarrhea   Fatigue & generalized bone ache   Jaundice   \
# 0     -1.005067                          1.002168   0.997836
# 1     -1.005067                          1.002168   0.997836
# 2      0.994959                         -0.997836  -1.002168
# 3      0.994959                         -0.997836   0.997836
# 4     -1.005067                          1.002168   0.997836
# ...         ...                               ...        ...
# 1380   0.994959                         -0.997836  -1.002168
# 1381  -1.005067                         -0.997836  -1.002168
# 1382  -1.005067                         -0.997836   0.997836
# 1383   0.994959                          1.002168   0.997836
# 1384   0.994959                         -0.997836   0.997836
#
#       Epigastric pain   ...    ALT 12    ALT 24    ALT 36    ALT 48  \
# 0             0.992089  ...  0.978295 -0.103412 -2.960181 -2.999471
# 1            -1.007974  ... -0.326634  1.118124 -0.989700  1.501857
# 2            -1.007974  ...  0.901534  1.232643 -2.960181 -2.999471
# 3            -1.007974  ... -0.134733  0.163799 -1.330745 -0.252898
# 4             0.992089  ... -1.362901  1.385335  0.412373  0.243011
# ...                ...  ...       ...       ...       ...       ...
# 1380         -1.007974  ...  0.863154  1.652546 -0.762337 -1.511744
# 1381         -1.007974  ...  0.594492  0.927259  0.526054 -0.748807
# 1382         -1.007974  ... -0.863957  1.232643  0.147116 -1.702479
# 1383         -1.007974  ... -0.365014 -1.401293 -1.330745 -0.100311
# 1384         -1.007974  ... -0.595296  1.194470 -0.724443 -0.481780
#
#       ALT after 24 w  RNA Base     RNA 4     RNA 12   RNA EOT    RNA EF
# 0          -4.021808  0.181960  0.092882  -0.001962 -1.087692 -1.088823
# 1           1.493666 -1.555454 -0.171903   1.221053  0.185824 -0.972681
# 2          -4.021808 -0.055972  0.166905  -1.012273  1.695069  0.999427
# 3          -0.061981  1.274675 -0.416795   1.040971  1.727277  1.087139
# 4          -0.486248  0.196318  0.380636  12.069419  0.193923 -0.181303
# ...              ...       ...       ...        ...       ...       ...
# 1380        1.635088 -0.574200 -1.504642  -1.012273 -1.087692 -1.088823
# 1381        1.069398 -0.309697 -1.236759   0.366648 -0.809510 -0.205921
# 1382       -1.334782  0.061369 -0.077694   1.813706  0.211971 -0.489235
# 1383        1.352243 -1.274928 -1.448806   0.795717 -1.078409  1.512293
# 1384        0.079442  1.694779  0.076851  -1.012273 -1.087692 -1.088823
#
# [1385 rows x 27 columns]

# %%
for column in std_pre_h_df.columns:
    std_pre_h_df = std_pre_h_df[std_pre_h_df[column].between(-1.96, 1.96)]

std_pre_h_df
# Out:
#           Age     Gender       BMI     Fever  Nausea/Vomting  Headache   \
# 1    -0.036355 -0.979276  0.096039 -1.031544        0.994959   1.007974
# 3     0.305396  1.021163  1.077696 -1.031544        0.994959  -0.992089
# 5     1.330647  1.021163 -1.621860  0.969420        0.994959   1.007974
# 6    -0.492022  1.021163 -0.640203 -1.031544       -1.005067   1.007974
# 7     0.191479  1.021163  0.341454 -1.031544       -1.005067   1.007974
# ...        ...       ...       ...       ...             ...        ...
# 1380 -0.264188 -0.979276  0.096039 -1.031544        0.994959   1.007974
# 1381  0.988897 -0.979276  1.323110 -1.031544        0.994959   1.007974
# 1382 -0.492022 -0.979276 -0.640203  0.969420        0.994959  -0.992089
# 1383  0.647146 -0.979276  0.096039  0.969420       -1.005067  -0.992089
# 1384  0.988897  1.021163 -0.640203 -1.031544        0.994959   1.007974
#
#       Diarrhea   Fatigue & generalized bone ache   Jaundice   \
# 1     -1.005067                          1.002168   0.997836
# 3      0.994959                         -0.997836   0.997836
# 5     -1.005067                          1.002168   0.997836
# 6      0.994959                          1.002168   0.997836
# 7      0.994959                         -0.997836  -1.002168
# ...         ...                               ...        ...
# 1380   0.994959                         -0.997836  -1.002168
# 1381  -1.005067                         -0.997836  -1.002168
# 1382  -1.005067                         -0.997836   0.997836
# 1383   0.994959                          1.002168   0.997836
# 1384   0.994959                         -0.997836   0.997836
#
#       Epigastric pain   ...    ALT 12    ALT 24    ALT 36    ALT 48  \
# 1            -1.007974  ... -0.326634  1.118124 -0.989700  1.501857
# 3            -1.007974  ... -0.134733  0.163799 -1.330745 -0.252898
# 5            -1.007974  ...  0.479351 -0.714179 -0.383398  1.158535
# 6             0.992089  ...  1.323717  0.889086  0.033434 -0.138458
# 7             0.992089  ...  1.669139 -1.477639  0.488160 -1.168423
# ...                ...  ...       ...       ...       ...       ...
# 1380         -1.007974  ...  0.863154  1.652546 -0.762337 -1.511744
# 1381         -1.007974  ...  0.594492  0.927259  0.526054 -0.748807
# 1382         -1.007974  ... -0.863957  1.232643  0.147116 -1.702479
# 1383         -1.007974  ... -0.365014 -1.401293 -1.330745 -0.100311
# 1384         -1.007974  ... -0.595296  1.194470 -0.724443 -0.481780
#
#       ALT after 24 w  RNA Base     RNA 4    RNA 12   RNA EOT    RNA EF
# 1           1.493666 -1.555454 -0.171903  1.221053  0.185824 -0.972681
# 3          -0.061981  1.274675 -0.416795  1.040971  1.727277  1.087139
# 5          -0.627670  1.601155  1.341738 -1.012273 -1.087692 -1.088823
# 6          -0.769093 -0.749722  1.195834 -0.047883 -0.276387  1.284654
# 7           0.786554  0.141822 -1.460156  1.747749  0.313633  0.803118
# ...              ...       ...       ...       ...       ...       ...
# 1380        1.635088 -0.574200 -1.504642 -1.012273 -1.087692 -1.088823
# 1381        1.069398 -0.309697 -1.236759  0.366648 -0.809510 -0.205921
# 1382       -1.334782  0.061369 -0.077694  1.813706  0.211971 -0.489235
# 1383        1.352243 -1.274928 -1.448806  0.795717 -1.078409  1.512293
# 1384        0.079442  1.694779  0.076851 -1.012273 -1.087692 -1.088823
#
# [1374 rows x 27 columns]

# %%
std_pre_h_df.loc[:, 'target'] = pre_h_df.loc[std_pre_h_df.index, 'target']
std_pre_h_df
# Out:
#           Age     Gender       BMI     Fever  Nausea/Vomting  Headache   \
# 1    -0.036355 -0.979276  0.096039 -1.031544        0.994959   1.007974
# 3     0.305396  1.021163  1.077696 -1.031544        0.994959  -0.992089
# 5     1.330647  1.021163 -1.621860  0.969420        0.994959   1.007974
# 6    -0.492022  1.021163 -0.640203 -1.031544       -1.005067   1.007974
# 7     0.191479  1.021163  0.341454 -1.031544       -1.005067   1.007974
# ...        ...       ...       ...       ...             ...        ...
# 1380 -0.264188 -0.979276  0.096039 -1.031544        0.994959   1.007974
# 1381  0.988897 -0.979276  1.323110 -1.031544        0.994959   1.007974
# 1382 -0.492022 -0.979276 -0.640203  0.969420        0.994959  -0.992089
# 1383  0.647146 -0.979276  0.096039  0.969420       -1.005067  -0.992089
# 1384  0.988897  1.021163 -0.640203 -1.031544        0.994959   1.007974
#
#       Diarrhea   Fatigue & generalized bone ache   Jaundice   \
# 1     -1.005067                          1.002168   0.997836
# 3      0.994959                         -0.997836   0.997836
# 5     -1.005067                          1.002168   0.997836
# 6      0.994959                          1.002168   0.997836
# 7      0.994959                         -0.997836  -1.002168
# ...         ...                               ...        ...
# 1380   0.994959                         -0.997836  -1.002168
# 1381  -1.005067                         -0.997836  -1.002168
# 1382  -1.005067                         -0.997836   0.997836
# 1383   0.994959                          1.002168   0.997836
# 1384   0.994959                         -0.997836   0.997836
#
#       Epigastric pain   ...    ALT 24    ALT 36    ALT 48  ALT after 24 w  \
# 1            -1.007974  ...  1.118124 -0.989700  1.501857        1.493666
# 3            -1.007974  ...  0.163799 -1.330745 -0.252898       -0.061981
# 5            -1.007974  ... -0.714179 -0.383398  1.158535       -0.627670
# 6             0.992089  ...  0.889086  0.033434 -0.138458       -0.769093
# 7             0.992089  ... -1.477639  0.488160 -1.168423        0.786554
# ...                ...  ...       ...       ...       ...             ...
# 1380         -1.007974  ...  1.652546 -0.762337 -1.511744        1.635088
# 1381         -1.007974  ...  0.927259  0.526054 -0.748807        1.069398
# 1382         -1.007974  ...  1.232643  0.147116 -1.702479       -1.334782
# 1383         -1.007974  ... -1.401293 -1.330745 -0.100311        1.352243
# 1384         -1.007974  ...  1.194470 -0.724443 -0.481780        0.079442
#
#       RNA Base     RNA 4    RNA 12   RNA EOT    RNA EF  target
# 1    -1.555454 -0.171903  1.221053  0.185824 -0.972681       2
# 3     1.274675 -0.416795  1.040971  1.727277  1.087139       3
# 5     1.601155  1.341738 -1.012273 -1.087692 -1.088823       4
# 6    -0.749722  1.195834 -0.047883 -0.276387  1.284654       4
# 7     0.141822 -1.460156  1.747749  0.313633  0.803118       3
# ...        ...       ...       ...       ...       ...     ...
# 1380 -0.574200 -1.504642 -1.012273 -1.087692 -1.088823       4
# 1381 -0.309697 -1.236759  0.366648 -0.809510 -0.205921       2
# 1382  0.061369 -0.077694  1.813706  0.211971 -0.489235       2
# 1383 -1.274928 -1.448806  0.795717 -1.078409  1.512293       3
# 1384  1.694779  0.076851 -1.012273 -1.087692 -1.088823       3
#
# [1374 rows x 28 columns]

# %%
pre_h_df = pre_h_df.iloc[std_pre_h_df.index]
pre_h_df
# Out:
#       Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 1       46       1   29      1               2          2          1
# 3       49       2   33      1               2          1          2
# 5       58       2   22      2               2          2          1
# 6       42       2   26      1               1          2          2
# 7       48       2   30      1               1          2          2
# ...    ...     ...  ...    ...             ...        ...        ...
# 1380    44       1   29      1               2          2          2
# 1381    55       1   34      1               2          2          1
# 1382    42       1   26      2               2          1          1
# 1383    52       1   29      2               1          1          2
# 1384    55       2   26      1               2          2          2
#
#       Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# 1                                    2          2                 1  ...
# 3                                    1          2                 1  ...
# 5                                    2          2                 1  ...
# 6                                    2          2                 2  ...
# 7                                    1          1                 2  ...
# ...                                ...        ...               ...  ...
# 1380                                 1          1                 1  ...
# 1381                                 1          1                 1  ...
# 1382                                 1          2                 1  ...
# 1383                                 2          2                 1  ...
# 1384                                 1          2                 1  ...
#
#       ALT 24  ALT 36  ALT 48  ALT after 24 w  RNA Base    RNA 4  RNA 12  \
# 1        113      57     123              44     40620   538635  637056
# 3         88      48      77              33   1041941   449939  585688
# 5         65      73     114              29   1157452  1086852       5
# 6        107      84      80              28    325694  1034008  275095
# 7         45      96      53              39    641129    72050  787295
# ...      ...     ...     ...             ...       ...      ...     ...
# 1380     127      63      44              45    387795    55938       5
# 1381     108      97      64              41    481378   152961  393339
# 1382     116      87      39              24    612664   572756  806109
# 1383      47      48      81              43    139872    76161  515730
# 1384     115      64      71              34   1190577   628730       5
#
#       RNA EOT  RNA EF  target
# 1      336804   31085       2
# 3      744463  582301       3
# 5           5       5       4
# 6      214566  635157       4
# 7      370605  506296       3
# ...       ...     ...     ...
# 1380        5       5       4
# 1381    73574  236273       2
# 1382   343719  160457       2
# 1383     2460  696074       3
# 1384        5       5       3
#
# [1374 rows x 28 columns]

# %%
std_pre_h_df.reset_index(drop=True, inplace=True)
pre_h_df.reset_index(drop=True, inplace=True)

# %%
from statsmodels.api import OLS

features, targets = pre_h_df.iloc[:, :-1], pre_h_df.iloc[:, -1]

model = OLS(targets, features)
print(model.fit().summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 target   R-squared (uncentered):                   0.839
# Model:                            OLS   Adj. R-squared (uncentered):              0.835
# Method:                 Least Squares   F-statistic:                              259.4
# Date:                Mon, 13 May 2024   Prob (F-statistic):                        0.00
# Time:                        01:15:27   Log-Likelihood:                         -2097.0
# No. Observations:                1374   AIC:                                      4248.
# Df Residuals:                    1347   BIC:                                      4389.
# Df Model:                          27
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Age                                  0.0004      0.003      0.116      0.908      -0.006       0.007
# Gender                               0.0646      0.061      1.066      0.287      -0.054       0.184
# BMI                                 -0.0062      0.007     -0.870      0.385      -0.020       0.008
# Fever                               -0.0264      0.060     -0.440      0.660      -0.144       0.091
# Nausea/Vomting                       0.1429      0.061      2.344      0.019       0.023       0.263
# Headache                             0.0232      0.061      0.382      0.703      -0.096       0.142
# Diarrhea                             0.0189      0.061      0.312      0.755      -0.100       0.138
# Fatigue & generalized bone ache      0.0721      0.060      1.192      0.233      -0.047       0.191
# Jaundice                             0.0814      0.060      1.352      0.177      -0.037       0.199
# Epigastric pain                     -0.0709      0.061     -1.163      0.245      -0.190       0.049
# WBC                               1.677e-05   1.14e-05      1.473      0.141   -5.57e-06    3.91e-05
# RBC                               2.311e-07   7.35e-08      3.145      0.002    8.69e-08    3.75e-07
# HGB                                  0.0265      0.017      1.564      0.118      -0.007       0.060
# Plat                             -2.338e-07   7.78e-07     -0.301      0.764   -1.76e-06    1.29e-06
# AST 1                               -0.0005      0.001     -0.451      0.652      -0.003       0.002
# ALT 1                                0.0023      0.001      1.913      0.056   -5.69e-05       0.005
# ALT4                              9.964e-05      0.001      0.087      0.930      -0.002       0.002
# ALT 12                               0.0007      0.001      0.577      0.564      -0.002       0.003
# ALT 24                               0.0004      0.001      0.338      0.735      -0.002       0.003
# ALT 36                               0.0005      0.001      0.474      0.636      -0.002       0.003
# ALT 48                               0.0005      0.001      0.468      0.640      -0.002       0.003
# ALT after 24 w                       0.0105      0.004      2.464      0.014       0.002       0.019
# RNA Base                          1.342e-07    8.6e-08      1.560      0.119   -3.45e-08    3.03e-07
# RNA 4                            -5.449e-08   8.41e-08     -0.648      0.517   -2.19e-07     1.1e-07
# RNA 12                            3.135e-07   1.32e-07      2.376      0.018    5.47e-08    5.72e-07
# RNA EOT                          -2.454e-07   1.36e-07     -1.801      0.072   -5.13e-07    2.18e-08
# RNA EF                            1.138e-07   1.35e-07      0.845      0.398    -1.5e-07    3.78e-07
# ==============================================================================
# Omnibus:                     2142.084   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               93.373
# Skew:                          -0.068   Prob(JB):                     5.30e-21
# Kurtosis:                       1.730   Cond. No.                     9.65e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 9.65e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def get_vif(features):
    vif = pd.DataFrame()
    vif['vif_score'] = [variance_inflation_factor(features.values, i) for i in range(features.shape[1])]
    vif['feature'] = features.columns
    return vif

# %%
get_vif(features)
# Out:
#     vif_score                           feature
# 0    1.012225                              Age
# 1    1.013414                            Gender
# 2    1.022307                               BMI
# 3    1.010625                             Fever
# 4    1.024626                    Nausea/Vomting
# 5    1.013890                         Headache
# 6    1.025597                         Diarrhea
# 7    1.017272  Fatigue & generalized bone ache
# 8    1.014629                         Jaundice
# 9    1.030852                  Epigastric pain
# 10   1.016839                               WBC
# 11   1.021125                               RBC
# 12   1.019078                               HGB
# 13   1.026275                              Plat
# 14   1.010611                             AST 1
# 15   1.028211                             ALT 1
# 16   1.022316                              ALT4
# 17   1.019214                            ALT 12
# 18   1.020385                            ALT 24
# 19   1.013623                            ALT 36
# 20   1.021323                            ALT 48
# 21   1.011558                    ALT after 24 w
# 22   1.011317                          RNA Base
# 23   1.019502                             RNA 4
# 24   1.383821                            RNA 12
# 25   1.388501                           RNA EOT
# 26   1.413813                            RNA EF

# %%
pre_h_df1 = pre_h_df.drop(labels=['Age ','Fever','Headache ','Diarrhea ','Plat','AST 1','ALT4','ALT 12','ALT 24','ALT 36','ALT 48','RNA 4','RNA EF'], axis=1)

# %%
from statsmodels.api import OLS

features, targets = pre_h_df1.iloc[:, :-1], pre_h_df1.iloc[:, -1]

model = OLS(targets, features)
print(model.fit().summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                 target   R-squared (uncentered):                   0.838
# Model:                            OLS   Adj. R-squared (uncentered):              0.837
# Method:                 Least Squares   F-statistic:                              503.7
# Date:                Mon, 13 May 2024   Prob (F-statistic):                        0.00
# Time:                        01:22:43   Log-Likelihood:                         -2098.5
# No. Observations:                1374   AIC:                                      4225.
# Df Residuals:                    1360   BIC:                                      4298.
# Df Model:                          14
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Gender                               0.0660      0.060      1.099      0.272      -0.052       0.184
# BMI                                 -0.0062      0.007     -0.883      0.377      -0.020       0.008
# Nausea/Vomting                       0.1461      0.060      2.432      0.015       0.028       0.264
# Fatigue & generalized bone ache      0.0750      0.060      1.254      0.210      -0.042       0.192
# Jaundice                             0.0857      0.060      1.440      0.150      -0.031       0.202
# Epigastric pain                     -0.0618      0.060     -1.032      0.302      -0.179       0.056
# WBC                               1.634e-05   1.13e-05      1.446      0.149   -5.83e-06    3.85e-05
# RBC                               2.495e-07   6.45e-08      3.870      0.000    1.23e-07    3.76e-07
# HGB                                  0.0274      0.017      1.651      0.099      -0.005       0.060
# ALT 1                                0.0022      0.001      1.930      0.054   -3.64e-05       0.005
# ALT after 24 w                       0.0107      0.004      2.530      0.012       0.002       0.019
# RNA Base                          1.377e-07   8.54e-08      1.613      0.107   -2.98e-08    3.05e-07
# RNA 12                            3.537e-07   1.24e-07      2.853      0.004    1.11e-07    5.97e-07
# RNA EOT                          -2.108e-07   1.28e-07     -1.645      0.100   -4.62e-07    4.05e-08
# ==============================================================================
# Omnibus:                     2310.235   Durbin-Watson:                   1.969
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               94.140
# Skew:                          -0.066   Prob(JB):                     3.61e-21
# Kurtosis:                       1.724   Cond. No.                     9.36e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 9.36e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# 차원축소후 훈련 진행

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

features, targets = pre_h_df1.iloc[:, :-1], pre_h_df1.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

smote = SMOTE(random_state=124)
over_X_train, over_y_train = smote.fit_resample(X_train, y_train)

# %% [markdown]
# 분류문제이기 때문에, LDA를 적용

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

for i in range(3):
    lda = LinearDiscriminantAnalysis(n_components=(i + 1))
    
    lda_train = lda.fit_transform(over_X_train, over_y_train)

    print(lda.explained_variance_ratio_.sum())
# Out:
# 0.6319415542909376
# 0.8911713613386452
# 1.0

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis(n_components=2)

lda_train = lda.fit_transform(over_X_train, over_y_train)

lda_columns = [f'lda{i + 1}' for i in range(lda_train.shape[1])]
lda_train_df = pd.DataFrame(lda_train, columns=lda_columns)
lda_train_df.loc[:, 'target'] = over_y_train

# %%
lda_train_df
# Out:
#           lda1      lda2  target
# 0     0.882088 -1.215986       4
# 1     1.482295 -0.589828       1
# 2     1.309397  0.373782       4
# 3     1.156290  0.085812       2
# 4     1.428835 -0.573040       1
# ...        ...       ...     ...
# 1139 -0.387003 -1.191233       2
# 1140  0.295536 -0.827383       2
# 1141  1.823378 -0.847667       2
# 1142 -0.517875  1.609246       3
# 1143 -1.388052  1.135986       3
#
# [1144 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x="lda1", y="lda2", hue='target', data=lda_train_df, alpha=0.5)
plt.show()

# %% [markdown]
# 2개의 차원으로 축소했을 때 이보다는 더 높게 줘야한다고 판단했다.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

parameters = {'rfc__max_depth': [5, 10, 20], 'rfc__min_samples_split': [10, 50, 100]}
rfc = RandomForestClassifier()

pipe = Pipeline([('std', StandardScaler()),
                 ('lda', LinearDiscriminantAnalysis(n_components=3)),
                 ('rfc', rfc)])

g_rfc = GridSearchCV(pipe, param_grid=parameters, cv=3, scoring='accuracy')
g_rfc.fit(over_X_train, over_y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('std', StandardScaler()),
#                                        ('lda',
#                                         LinearDiscriminantAnalysis(n_components=3)),
#                                        ('rfc', RandomForestClassifier())]),
#              param_grid={'rfc__max_depth': [5, 10, 20],
#                          'rfc__min_samples_split': [10, 50, 100]},
#              scoring='accuracy')

# %%
result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                               params  mean_test_score  \
# 0  {'rfc__max_depth': 5, 'rfc__min_samples_split'...         0.252601
# 1  {'rfc__max_depth': 5, 'rfc__min_samples_split'...         0.246474
# 2  {'rfc__max_depth': 5, 'rfc__min_samples_split'...         0.250853
# 3  {'rfc__max_depth': 10, 'rfc__min_samples_split...         0.252605
# 4  {'rfc__max_depth': 10, 'rfc__min_samples_split...         0.254341
# 5  {'rfc__max_depth': 10, 'rfc__min_samples_split...         0.256957
# 6  {'rfc__max_depth': 20, 'rfc__min_samples_split...         0.247365
# 7  {'rfc__max_depth': 20, 'rfc__min_samples_split...         0.258723
# 8  {'rfc__max_depth': 20, 'rfc__min_samples_split...         0.258723
#
#    rank_test_score
# 0                6
# 1                9
# 2                7
# 3                5
# 4                4
# 5                3
# 6                8
# 7                1
# 8                1

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay

def get_evaluation(y_test, prediction, classifier=None, X_test=None):
    confusion = confusion_matrix(y_test, prediction)
    accuracy = accuracy_score(y_test , prediction)
    precision = precision_score(y_test , prediction, average='macro')
    recall = recall_score(y_test , prediction, average='macro')
    f1 = f1_score(y_test, prediction, average='macro')
    
    print('오차 행렬')
    print(confusion)
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}'.format(accuracy, precision, recall, f1))
    print("#" * 80)
    
    if classifier is not None and  X_test is not None:
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,4))
        titles_options = [("Confusion matrix", None), ("Normalized confusion matrix", "true")]

        for (title, normalize), ax in zip(titles_options, axes.flatten()):
            disp = ConfusionMatrixDisplay.from_estimator(classifier, X_test, y_test, ax=ax, cmap=plt.cm.Blues, normalize=normalize)
            disp.ax_.set_title(title)
        plt.show()

# %%
rfc = g_rfc.best_estimator_
prediction = rfc.predict(X_test)
get_evaluation(y_test, prediction)
# Out:
# 오차 행렬
# [[19 12 17 19]
#  [10 21 16 19]
#  [16 18 14 23]
#  [15 17 13 26]]
# 정확도: 0.2909, 정밀도: 0.2894, 재현율: 0.2913, F1: 0.2889
# ################################################################################

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

features, targets = pre_h_df1.iloc[:, :-1], pre_h_df1.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

smote = SMOTE(random_state=124)
over_X_train, over_y_train = smote.fit_resample(X_train, y_train)

# %%
X_train.shape
# Out:
# (1099, 14)

# %%
over_X_train.shape
# Out:
# (1144, 14)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

for i in range(2):
    lda = LinearDiscriminantAnalysis(n_components=(i + 1))
    
    lda_train = lda.fit_transform(over_X_train, over_y_train)

    print(lda.explained_variance_ratio_.sum())
# Out:
# 0.6319415542909376
# 0.8911713613386452

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

parameters = {'rfc__max_depth': [5, 10, 20], 'rfc__min_samples_split': [10, 50, 100]}
rfc = RandomForestClassifier()

pipe = Pipeline([('std', StandardScaler()),
                 ('lda', LinearDiscriminantAnalysis(n_components=1)),
                 ('rfc', rfc)])

g_rfc = GridSearchCV(pipe, param_grid=parameters, cv=3, scoring='accuracy')
g_rfc.fit(over_X_train, over_y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('std', StandardScaler()),
#                                        ('lda',
#                                         LinearDiscriminantAnalysis(n_components=1)),
#                                        ('rfc', RandomForestClassifier())]),
#              param_grid={'rfc__max_depth': [5, 10, 20],
#                          'rfc__min_samples_split': [10, 50, 100]},
#              scoring='accuracy')

# %%
rfc = g_rfc.best_estimator_
prediction = rfc.predict(X_test)
get_evaluation(y_test, prediction)
# Out:
# 오차 행렬
# [[20 16 14 17]
#  [13 17 21 15]
#  [18 16 19 18]
#  [19 13 16 23]]
# 정확도: 0.2873, 정밀도: 0.2866, 재현율: 0.2869, F1: 0.2866
# ################################################################################

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

features, targets = pre_h_df.iloc[:, :-1], pre_h_df.iloc[:, -1]

X_train, X_test, y_train, y_test = \
train_test_split(features, targets, stratify=targets, test_size=0.2, random_state=124)

smote = SMOTE(random_state=124)
over_X_train, over_y_train = smote.fit_resample(X_train, y_train)

# %%
train_df = pd.concat([over_X_train, over_y_train], axis=1).reset_index(drop=True)
test_df = pd.concat([X_test, y_test], axis=1).reset_index(drop=True)

# %%
display(train_df)
display(test_df)
# Out:
#       Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0       50       1   30      1               1          2          1
# 1       32       1   31      1               1          2          2
# 2       52       1   33      1               2          2          2
# 3       57       2   30      1               1          2          1
# 4       57       1   31      2               1          1          1
# ...    ...     ...  ...    ...             ...        ...        ...
# 1139    45       1   29      1               1          1          1
# 1140    55       1   26      1               1          2          2
# 1141    48       1   32      1               1          1          1
# 1142    39       2   30      2               2          1          1
# 1143    41       2   29      1               2          1          1
#
#       Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# 0                                    2          2                 2  ...
# 1                                    1          2                 2  ...
# 2                                    1          2                 2  ...
# 3                                    2          1                 2  ...
# 4                                    1          1                 2  ...
# ...                                ...        ...               ...  ...
# 1139                                 1          2                 2  ...
# 1140                                 2          1                 2  ...
# 1141                                 1          1                 2  ...
# 1142                                 1          1                 1  ...
# 1143                                 1          1                 1  ...
#
#       ALT 24  ALT 36  ALT 48  ALT after 24 w  RNA Base    RNA 4  RNA 12  \
# 0        115     113      44              39    680646   572994       5
# 1        116      77      84              36    412610   296747  105295
# 2         86      55      76              43    305363   437085   72642
# 3         88     109     114              32    497247  1126028       5
# 4        119      51     116              22    535019   880812       5
# ...      ...     ...     ...             ...       ...      ...     ...
# 1139      47      97      69              42    448794   927296  432594
# 1140      60      84      81              38    367506  1148452  181468
# 1141     113      54      61              30    125292   183994       5
# 1142      67      75     117              33    773290   260662  560206
# 1143      84     117      86              42    830772   489276       5
#
#       RNA EOT  RNA EF  target
# 0           5       5       4
# 1      214813  435383       1
# 2      602681  694737       4
# 3           5       5       2
# 4           5       5       1
# ...       ...     ...     ...
# 1139   111735  518822       2
# 1140   623274  308178       2
# 1141        5       5       2
# 1142   343032  319722       3
# 1143        5       5       3
#
# [1144 rows x 28 columns]
#      Age   Gender  BMI  Fever  Nausea/Vomting  Headache   Diarrhea   \
# 0      40       2   33      2               1          2          2
# 1      46       1   24      1               1          2          2
# 2      45       1   32      2               1          2          1
# 3      35       2   25      2               2          1          2
# 4      33       1   28      2               2          1          2
# ..    ...     ...  ...    ...             ...        ...        ...
# 270    53       1   34      1               2          1          2
# 271    41       1   30      1               2          2          1
# 272    42       2   26      1               1          2          2
# 273    33       1   26      1               2          2          2
# 274    37       1   34      2               1          2          1
#
#      Fatigue & generalized bone ache   Jaundice   Epigastric pain   ...  \
# 0                                   1          2                 2  ...
# 1                                   1          2                 1  ...
# 2                                   1          1                 1  ...
# 3                                   2          2                 1  ...
# 4                                   1          2                 1  ...
# ..                                ...        ...               ...  ...
# 270                                 2          1                 2  ...
# 271                                 2          2                 2  ...
# 272                                 2          2                 2  ...
# 273                                 1          1                 1  ...
# 274                                 1          2                 1  ...
#
#      ALT 24  ALT 36  ALT 48  ALT after 24 w  RNA Base    RNA 4  RNA 12  \
# 0       115      40      62              34    602881   294175  129442
# 1        56      49     121              37    373305   640478  781722
# 2        63      44      80              22    207727    10743  500170
# 3        68      64     115              24    544755  1173393  531800
# 4       108      87     128              41    801151   347194  573052
# ..      ...     ...     ...             ...       ...      ...     ...
# 270      91      99      61              43    607176   559364       5
# 271      40      56      96              34   1123536   402548       5
# 272     107      84      80              28    325694  1034008  275095
# 273     112     107      50              39    771499  1185368  588399
# 274      98     114      57              26    219704  1051314       5
#
#      RNA EOT  RNA EF  target
# 0     727795  515288       1
# 1     726923  672459       2
# 2     356630  372348       3
# 3     607666  288955       3
# 4      82400  667558       2
# ..       ...     ...     ...
# 270        5       5       1
# 271        5       5       1
# 272   214566  635157       4
# 273   599161  158901       1
# 274        5       5       2
#
# [275 rows x 28 columns]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis(n_components=1)

lda_train = lda.fit_transform(train_df.iloc[:, :-1], train_df.iloc[:, -1])
lda_test = lda.fit_transform(test_df.iloc[:, :-1], test_df.iloc[:, -1])

print(lda_train.shape, lda_test.shape)
# Out:
# (1144, 1) (275, 1)

# %%
lda_columns = [f'lda{i + 1}' for i in range(lda_train.shape[1])]
lda_train_df = pd.DataFrame(lda_train, columns=lda_columns)
lda_train_df.loc[:, 'target'] = train_df['target']

lda_columns = [f'lda{i + 1}' for i in range(lda_test.shape[1])]
lda_test_df = pd.DataFrame(lda_test, columns=lda_columns)
lda_test_df.loc[:, 'target'] = test_df['target']

# %%
display(lda_train_df)
display(lda_test_df)
# Out:
#           lda1  target
# 0     0.956890       4
# 1     0.532091       1
# 2     0.616799       4
# 3     2.409702       2
# 4     1.529638       1
# ...        ...     ...
# 1139  0.379228       2
# 1140  1.738487       2
# 1141  1.170414       2
# 1142 -0.786167       3
# 1143 -1.054757       3
#
# [1144 rows x 2 columns]
#          lda1  target
# 0    0.429118       1
# 1    0.048997       2
# 2   -1.718042       3
# 3   -1.484269       3
# 4   -0.708003       2
# ..        ...     ...
# 270  0.599999       1
# 271 -0.120647       1
# 272  0.343307       4
# 273  2.597362       1
# 274 -0.700454       2
#
# [275 rows x 2 columns]

# %%
print(lda.explained_variance_ratio_)
print(lda.explained_variance_ratio_.sum())
# Out:
# [0.43559835]
# 0.4355983473177599

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

features, targets = lda_train_df.iloc[:, :-1], lda_train_df.iloc[:, -1]
parameters = {'max_depth': [5, 10, 20], 'min_samples_split': [10, 50, 100]}

rfc = RandomForestClassifier()
# import sklearn
# sklearn.metrics.SCORERS.keys()
g_rfc = GridSearchCV(rfc, param_grid=parameters, cv=5, return_train_score=True, scoring='accuracy')
g_rfc.fit(features, targets)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [5, 10, 20],
#                          'min_samples_split': [10, 50, 100]},
#              return_train_score=True, scoring='accuracy')

# %%
result_df = pd.DataFrame(g_rfc.cv_results_)[['params', 'mean_test_score', 'rank_test_score']]
display(result_df)
# Out:
#                                         params  mean_test_score  \
# 0    {'max_depth': 5, 'min_samples_split': 10}         0.294599
# 1    {'max_depth': 5, 'min_samples_split': 50}         0.287589
# 2   {'max_depth': 5, 'min_samples_split': 100}         0.270984
# 3   {'max_depth': 10, 'min_samples_split': 10}         0.261331
# 4   {'max_depth': 10, 'min_samples_split': 50}         0.268337
# 5  {'max_depth': 10, 'min_samples_split': 100}         0.274489
# 6   {'max_depth': 20, 'min_samples_split': 10}         0.257856
# 7   {'max_depth': 20, 'min_samples_split': 50}         0.249123
# 8  {'max_depth': 20, 'min_samples_split': 100}         0.274477
#
#    rank_test_score
# 0                1
# 1                2
# 2                5
# 3                7
# 4                6
# 5                3
# 6                8
# 7                9
# 8                4

# %%
X_test, y_test = lda_test_df.iloc[:, :-1], lda_test_df.iloc[:, -1]

rfc = g_rfc.best_estimator_
prediction = rfc.predict(X_test)
get_evaluation(y_test, prediction, rfc, X_test)
# Out:
# 오차 행렬
# [[11 26 21  9]
#  [12  8 11 35]
#  [12 10 24 25]
#  [16 17 21 17]]
# 정확도: 0.2182, 정밀도: 0.2140, 재현율: 0.2157, F1: 0.2133
# ################################################################################
